# %%
#Spotify Şarkılarının Keşifsel Veri Analizi (EDA) ile İncelenmesi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('mydata/SpotifyFeatures.csv')
df.head(10)
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# 5       Curbo  26Y1lX7ZOpw9Ql3gGAlqLK
# 6  Bingo Play  5eIyK73BrxHLnly4F9PWqg
# 7     G Herbo  13Mf2ZBpfNkgWJowvM5hXh
# 8     34 Feet  7BQaRTHk44DkMhIVNcXy2D
# 9  Chris Cooq  049RxG2laEl9U1PGYeIqLV
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
# ...

# %%
df.drop("time_signature", axis = 1, inplace = True)

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# ...

# %%
df.nunique()
# Out:
# artist_name          34621
# track_id            130326
# track_name          108890
# acousticness          4908
# danceability          1257
# duration_ms          77897
# energy                2571
# instrumentalness      5387
# key                     12
# liveness              1717
# loudness             25888
# mode                     2
# speechiness           1616
# tempo                57314
# valence               1918
# popularity             100
# dtype: int64

# %%
df.isnull().sum()
# Out:
# artist_name         0
# track_id            0
# track_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130663 entries, 0 to 130662
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist_name       130663 non-null  object
#  1   track_id          130663 non-null  object
#  2   track_name        130663 non-null  object
#  3   acousticness      130663 non-null  float64
#  4   danceability      130663 non-null  float64
#  5   duration_ms       130663 non-null  int64
#  6   energy            130663 non-null  float64
#  7   instrumentalness  130663 non-null  float64
#  8   key               130663 non-null  int64
#  9   liveness          130663 non-null  float64
#  10  loudness          130663 non-null  float64
#  11  mode              130663 non-null  int64
#  12  speechiness       130663 non-null  float64
#  13  tempo             130663 non-null  float64
#  14  valence           130663 non-null  float64
# ...

# %%
df.shape
# Out:
# (130663, 16)

# %%
len(df.columns)
# Out:
# 16

# %%
df.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  130663.000000  130663.000000  1.306630e+05  130663.000000
# mean        0.342500       0.581468  2.126331e+05       0.569196
# std         0.345641       0.190077  1.231551e+05       0.260312
# min         0.000000       0.000000  3.203000e+03       0.000000
# 25%         0.031600       0.459000  1.639225e+05       0.396000
# 50%         0.203000       0.605000  2.019010e+05       0.603000
# 75%         0.636000       0.727000  2.410475e+05       0.775000
# max         0.996000       0.996000  5.610020e+06       1.000000
#
#        instrumentalness            key       liveness       loudness  \
# count     130663.000000  130663.000000  130663.000000  130663.000000
# mean           0.224018       5.231894       0.194886      -9.974006
# std            0.360328       3.602701       0.167733       6.544379
# min            0.000000       0.000000       0.000000     -60.000000
# ...

# %%
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  \
# acousticness          1.000000     -0.360462     0.033426 -0.710067
# danceability         -0.360462      1.000000    -0.126781  0.286196
# duration_ms           0.033426     -0.126781     1.000000 -0.019885
# energy               -0.710067      0.286196    -0.019885  1.000000
# instrumentalness      0.272685     -0.305112     0.029124 -0.301308
# key                  -0.019987      0.021123    -0.001880  0.039843
# liveness             -0.100545     -0.137377    -0.003661  0.209448
# loudness             -0.603366      0.431554    -0.018595  0.766697
# mode                  0.067171     -0.057912     0.010321 -0.069263
# speechiness          -0.119231      0.248192    -0.101955  0.105078
# tempo                -0.216328      0.081791    -0.009657  0.229930
# valence              -0.177023      0.461468    -0.141837  0.314768
# popularity           -0.116520      0.131086    -0.000801  0.122506
#
# ...

# %%
top_five_artists = df.value_counts("artist_name").head()
top_five_artists
# Out:
# artist_name
# Johann Sebastian Bach      3621
# Wolfgang Amadeus Mozart    1755
# Armin van Buuren           1124
# Ludwig van Beethoven        928
# Frédéric Chopin             614
# dtype: int64

# %%
top_five_artists.plot.barh()
plt.show()

# %%
top_twenty_loudest_track = df[["loudness", "track_name", "artist_name"]].sort_values(by = 'loudness', ascending = False).head(20)
top_twenty_loudest_track
# Out:
#         loudness                     track_name  \
# 24318      1.806                           Bass
# 20658      1.750              The Diarrhea Song
# 23640      1.187                       Lalalala
# 98408      0.935          Sajan Mara Dilni Rani
# 99459      0.905        Jija Ji Devghar Ghumadi
# 76292      0.843                          Wings
# 60472      0.805                     No Advance
# 69314      0.738                       Together
# 71266      0.726          The Festival Of Blood
# 40710      0.681              Thermal Expansion
# 91637      0.679                  Ready 2 Party
# 8361       0.642                       Rockstar
# 68883      0.636                    Spit It Out
# 101884     0.634                       Sell Out
# 23386      0.612                   Menina Braba
# 129301     0.598                            WTF
# 116637     0.594              Are You Sure Now?
# 68399      0.584                      All Night
# ...

# %%
plt.figure(figsize = (12,7))
sns.barplot(x = "loudness", y = 'artist_name', data = top_twenty_loudest_track)
plt.title("Most dancable tracks")
plt.show()

# %%
most_dancable_track = df[["danceability", "track_name", "artist_name"]].sort_values(by = 'danceability', ascending = False).head(5)
most_dancable_track
# Out:
#        danceability            track_name        artist_name
# 35119         0.996            Tappy Toes         Louie Zong
# 68976         0.986      Familiar Feeling             TÂCHES
# 82706         0.986            No Worries       Jean Tonique
# 23717         0.986  Jazzy Guitars Needed       DJ Juan 9000
# 66741         0.986          Paper Plates  The Real Triple D

# %%
plt.figure(figsize = (12,7))
sns.barplot(x = "danceability", y = 'track_name', data = most_dancable_track)
plt.title("Most dancable tracks")
plt.show()

# %%
top_ten_inst_track = df[["instrumentalness", "track_name", "artist_name"]].sort_values("instrumentalness", ascending = False).head(10)
top_ten_inst_track
# Out:
#        instrumentalness                                         track_name  \
# 98698               1.0                                   Soft Brown Noise
# 68402               1.0                                Gentle Thunderstorm
# 58349               1.0                           Relaxing White Noise One
# 98021               1.0                               Monotone White Noise
# 40213               1.0                            Brownian Binaural Bliss
# 71882               1.0                                    The Brown Noise
# 30947               1.0                               Sweeping White Noise
# 90227               1.0           Pink Noise for Babies (Free Sleep Noise)
# 86502               1.0  REM Sleep and Inner Peace (Theta Waves) - Loop...
# 49153               1.0                                Noise Blocking Pink
#
#                                             artist_name
# 98698                             High Altitude Samples
# ...

# %%
plt.figure(figsize = (12,5))
labels = top_ten_inst_track['track_name']
plt.pie(x = 'instrumentalness', data = top_ten_inst_track, autopct = '%1.2f%%', labels = labels)
plt.title('Top 10 Inst Tracks')
plt.show()

# %%
popularity_more_than_70 = df[df.popularity > 70].sort_values(by = "popularity", ascending = False)
popularity_more_than_70
# Out:
#               artist_name                track_id  \
# 99393        Daddy Yankee  5w9c2J52mkdntKOmRLeM2m
# 99366      Jonas Brothers  4y3OI86AEP6PQoDE6olYhO
# 123909        Post Malone  3KkXRkHbMCARz0aVfEt68P
# 99364         Post Malone  6MWtB6iiXyIwun0YzU6DFP
# 99368       Billie Eilish  2Fxmhks0bxGSBdJ92vM42m
# ...                   ...                     ...
# 120776          Lil Wayne  0CBQ0m3mufWH75LTYB3s6h
# 101781              Gunna  6PfI6EeLNiNGVAVg11nv7D
# 124638  Twenty One Pilots  7daBwTiPNOVgoMUG4SICgh
# 98927      James Morrison  0irDfV3ctQGVN69ograYiK
# 120913          Joey Trap  2mGsE1qEjglIN1Ai4egOBO
#
#                                            track_name  acousticness  \
# 99393                                       Con Calma       0.11000
# 99366                                          Sucker       0.04270
# 123909  Sunflower - Spider-Man: Into the Spider-Verse       0.52000
# 99364                                            Wow.       0.16300
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(popularity_more_than_70['acousticness'], color = 'green')
plt.title("Acousticness for songs with more than 70 popularity")
plt.show()

# %%
#Project-2 -> World Population

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

# %%
data = pd.read_csv('mydata/world_population.csv')
data
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
continent_data = data.groupby(by = 'Continent').sum()
continent_data.head(10)
# Out:
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253       1426730932       1360671810       1201102442
# Asia           3878       4721383274       4663086535       4458250182
# Europe         6225        743147538        745792196        741535608
# North America  6437        600296136        594236593        570383850
# Oceania        4336         45038554         43933426         40403283
# South America  1366        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
data.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
data.describe(include = "object")
# Out:
#        CCA3         Country/Territory   Capital Continent
# count   234                       234       234       234
# unique  234                       234       234         6
# top     COM  Central African Republic  Santiago    Africa
# freq      1                         1         1        57

# %%
data.describe(include = 'all')
# Out:
#               Rank CCA3         Country/Territory   Capital Continent  \
# count   234.000000  234                       234       234       234
# unique         NaN  234                       234       234         6
# top            NaN  COM  Central African Republic  Santiago    Africa
# freq           NaN    1                         1         1        57
# mean    117.500000  NaN                       NaN       NaN       NaN
# std      67.694165  NaN                       NaN       NaN       NaN
# min       1.000000  NaN                       NaN       NaN       NaN
# 25%      59.250000  NaN                       NaN       NaN       NaN
# 50%     117.500000  NaN                       NaN       NaN       NaN
# 75%     175.750000  NaN                       NaN       NaN       NaN
# max     234.000000  NaN                       NaN       NaN       NaN
#
#         2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
data.shape
# Out:
# (234, 17)

# %%
data.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country/Territory              234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
data.mode()
# Out:
#      Rank CCA3  Country/Territory       Capital Continent  2022 Population  \
# 0       1  ABW        Afghanistan     Abu Dhabi    Africa              510
# 1       2  AFG            Albania         Abuja       NaN             1871
# 2       3  AGO            Algeria         Accra       NaN             1934
# 3       4  AIA     American Samoa   Addis Ababa       NaN             3780
# 4       5  ALB            Andorra       Algiers       NaN             4390
# ..    ...  ...                ...           ...       ...              ...
# 229   230  WSM  Wallis and Futuna  Yamoussoukro       NaN        235824862
# 230   231  YEM     Western Sahara       Yaounde       NaN        275501339
# 231   232  ZAF              Yemen         Yaren       NaN        338289857
# 232   233  ZMB             Zambia       Yerevan       NaN       1417173173
# 233   234  ZWE           Zimbabwe        Zagreb       NaN       1425887337
#
# ...

# %%
data['2022 Population'].sum()
# Out:
# 7973413042

# %%
data.rename(columns = {'Country/Territory' : 'Country'}, inplace = True)
data.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
plt.figure(figsize = (100, 50))
plt.title('Histogram for Rank vs Country')
plt.xlabel('Country', color = 'green')
plt.ylabel('Rank', color = 'green')
sns.barplot(data = data, x = 'Country', y = 'Rank')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.title('Growth Rate vs Continent')
#plt.hist(data = data, x = 'Growth Rate')
sns.barplot(data = data, y = 'Growth Rate', x = 'Continent')
plt.ylim(0, 1.50)
plt.xticks(rotation = 45)
plt.show()

# %%
plt.subplots(figsize = (10,5))
since = data.iloc[:, 5:13].sum()[::-1]
sns.lineplot(x = since.index, y = since.values, marker = 'o')
plt.xticks(rotation = 45)
plt.ylabel('Population')
plt.title('World Population Since (1970-2022)', color = 'Blue')
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.title('Growth Rate of WP')
sns.countplot(data = data, x = 'Growth Rate')
plt.ylim(0, 5.0)
plt.show()

# %%
turkey_data = data[data['Country'] == 'Turkey']

pop_1970 = turkey_data['1970 Population'].iloc[0]
pop_2022 = turkey_data['2022 Population'].iloc[0]

plt.figure(figsize = (10,6))
plt.bar(x = ['1970 Population', '2022 Population'], height = [pop_1970, pop_2022])
plt.ylabel('Population', color = 'Green')
plt.xlabel('1970 vs 2022 Population', color = 'Green')
plt.title('Population of Turkey in 1970 and 2022', color = 'Green')
plt.show()

# %%
pakistan_data = data[data['Country'] == 'Pakistan']
china_data = data[data['Country'] == 'China']
india_data = data[data['Country'] == 'India']
usa_data = data[data['Country'] == 'United States']
indo_data = data[data['Country'] == 'Indonesia']

pop_pakistan = pakistan_data['2022 Population'].iloc[0]
pop_china = china_data['2022 Population'].iloc[0]
pop_india = india_data['2022 Population'].iloc[0]
pop_usa = usa_data['2022 Population'].iloc[0]
pop_indo = indo_data['2022 Population'].iloc[0]

fig, ax = plt.subplots(figsize = (10,6))
labels = ['Pakistan', 'China', 'India', 'USA', 'Indo']
sizes = [pop_pakistan, pop_china, pop_india, pop_usa, pop_indo]
ax.pie(sizes, labels = labels, autopct = '%1.1f%%')
ax.set_title('Top-5 Countries population in 2022')
plt.show()

# %%
continent_data = data.groupby('Continent').sum()

fig,ax = plt.subplots(figsize = (8,6))
ax.pie(continent_data['2022 Population'], labels = continent_data.index, autopct = '%1.1f%%')
ax.set_title('population by continent (2022)')
plt.show()

# %%
pakistan_data = data[data['Country'] == 'Pakistan']

pop_1970 = pakistan_data['1970 Population'].iloc[0]
pop_1980 = pakistan_data['1980 Population'].iloc[0]
pop_1990 = pakistan_data['1990 Population'].iloc[0]
pop_2000 = pakistan_data['2000 Population'].iloc[0]
pop_2010 = pakistan_data['2010 Population'].iloc[0]
pop_2015 = pakistan_data['2015 Population'].iloc[0]
pop_2020 = pakistan_data['2020 Population'].iloc[0]
pop_2022 = pakistan_data['2022 Population'].iloc[0]

increment_1970_1980 = pop_1980 + pop_1970
increment_1980_1990 = pop_1990 + pop_1980
increment_1990_2000 = pop_2000 + pop_1990
increment_2000_2010 = pop_2010 + pop_2000
increment_2010_2015 = pop_2015 + pop_2010
increment_2015_2020 = pop_2020 + pop_2015
increment_2020_2022 = pop_2022 + pop_2020

plt.figure(figsize = (12,6))
plt.plot(['1970-1980','1980-1990','1990-2000','2000-2010','2010-2015','2015-2020','2020-2022'],
        [increment_1970_1980, increment_1980_1990, increment_1990_2000, increment_2000_2010,
        increment_2010_2015, increment_2015_2020, increment_2020_2022], marker = 'o')

plt.xlabel('Time Period')
plt.xticks(rotation = 45)
plt.ylabel('Population Increment')
plt.title('Pop. Increment of Pakistan from 1970-2022')
plt.show()
