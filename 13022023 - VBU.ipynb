# %%
import pandas as pd
s5 = pd.Series([1, 1, 2, 2, 3, 3], index = [0, 1, 2, 3, 4, 5])
s5
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# dtype: int64

# %%
s5.value_counts()
# Out:
# 1    2
# 2    2
# 3    2
# dtype: int64

# %%
#Dataframes (Veri çerçeveleri)

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lang = ['Java', 'Python', 'C', 'C++']
df = pd.DataFrame(lang)
df
# Out:
#         0
# 0    Java
# 1  Python
# 2       C
# 3     C++

# %%
rating = [1,2,3,4]
df[1] = rating
df
# Out:
#         0  1
# 0    Java  1
# 1  Python  2
# 2       C  3
# 3     C++  4

# %%
df.columns = ['Language', 'Rating']

# %%
df
# Out:
#   Language  Rating
# 0     Java       1
# 1   Python       2
# 2        C       3
# 3      C++       4

# %%
#Sözlükten DF üretimi
data = [{'a' : 1, 'b' : 2},  {'a' : 5, 'b' : 10, 'c' : 20}]

df2 = pd.DataFrame(data)
df3 = pd.DataFrame(data, index = ['row1', 'row2'], columns = ['a', 'b'])

# %%
df2
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
df3
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
df4 = pd.DataFrame(data, index = ['row1', 'row2'], columns = ['a', 'b', 'c'])
df5 = pd.DataFrame(data, index = ['row1' ,'row2'], columns = ['a', 'b', 'c', 'd'])
df4
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
dict = {'A' : pd.Series([1,2,3], index = ['a', 'b', 'c']),
        'B' : pd.Series([1,2,3,4], index = ['a', 'b', 'c', 'd'])}

df1 = pd.DataFrame(dict)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  NaN  4

# %%
dates = pd.date_range(start = '2023-02-13', end = '2023-02-19')
dates
# Out:
# DatetimeIndex(['2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16',
#                '2023-02-17', '2023-02-18', '2023-02-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods = 7)
dates
# Out:
# DatetimeIndex(['2023-02-13 21:30:26.183935', '2023-02-14 21:30:26.183935',
#                '2023-02-15 21:30:26.183935', '2023-02-16 21:30:26.183935',
#                '2023-02-17 21:30:26.183935', '2023-02-18 21:30:26.183935',
#                '2023-02-19 21:30:26.183935'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range(start = '2023-02-13', periods = 7)
dates
# Out:
# DatetimeIndex(['2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16',
#                '2023-02-17', '2023-02-18', '2023-02-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
M = np.random.random((7,7))
M
# Out:
# array([[0.43314477, 0.79881595, 0.6616637 , 0.73126924, 0.4533126 ,
#         0.7205852 , 0.56292426],
#        [0.57369972, 0.34416481, 0.44076305, 0.06106769, 0.5106548 ,
#         0.41873273, 0.10796153],
#        [0.3696259 , 0.22623229, 0.11247011, 0.3322916 , 0.17717498,
#         0.76742135, 0.85566115],
#        [0.91654812, 0.94967068, 0.07950952, 0.75462192, 0.26855796,
#         0.87063772, 0.14858507],
#        [0.25237439, 0.72946359, 0.09872702, 0.32678829, 0.06894428,
#         0.81543865, 0.696618  ],
#        [0.84073163, 0.23025742, 0.30758066, 0.05380075, 0.97064636,
#         0.62422921, 0.76095803],
#        [0.57038305, 0.28051262, 0.52593003, 0.40127651, 0.754004  ,
#         0.22445928, 0.1014568 ]])

# %%
dframe = pd.DataFrame(M, index = dates)
dframe
# Out:
#                    0         1         2         3         4         5  \
# 2023-02-13  0.433145  0.798816  0.661664  0.731269  0.453313  0.720585
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-15  0.369626  0.226232  0.112470  0.332292  0.177175  0.767421
# 2023-02-16  0.916548  0.949671  0.079510  0.754622  0.268558  0.870638
# 2023-02-17  0.252374  0.729464  0.098727  0.326788  0.068944  0.815439
# 2023-02-18  0.840732  0.230257  0.307581  0.053801  0.970646  0.624229
# 2023-02-19  0.570383  0.280513  0.525930  0.401277  0.754004  0.224459
#
#                    6
# 2023-02-13  0.562924
# 2023-02-14  0.107962
# 2023-02-15  0.855661
# 2023-02-16  0.148585
# 2023-02-17  0.696618
# 2023-02-18  0.760958
# 2023-02-19  0.101457

# %%
dframe.columns = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7']
dframe
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-02-13  0.433145  0.798816  0.661664  0.731269  0.453313  0.720585
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-15  0.369626  0.226232  0.112470  0.332292  0.177175  0.767421
# 2023-02-16  0.916548  0.949671  0.079510  0.754622  0.268558  0.870638
# 2023-02-17  0.252374  0.729464  0.098727  0.326788  0.068944  0.815439
# 2023-02-18  0.840732  0.230257  0.307581  0.053801  0.970646  0.624229
# 2023-02-19  0.570383  0.280513  0.525930  0.401277  0.754004  0.224459
#
#                   C7
# 2023-02-13  0.562924
# 2023-02-14  0.107962
# 2023-02-15  0.855661
# 2023-02-16  0.148585
# 2023-02-17  0.696618
# 2023-02-18  0.760958
# 2023-02-19  0.101457

# %%
dframe.dtypes
# Out:
# C1    float64
# C2    float64
# C3    float64
# C4    float64
# C5    float64
# C6    float64
# C7    float64
# dtype: object

# %%
#Sıralama
dframe.sort_values(by = 'C1')
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-02-17  0.252374  0.729464  0.098727  0.326788  0.068944  0.815439
# 2023-02-15  0.369626  0.226232  0.112470  0.332292  0.177175  0.767421
# 2023-02-13  0.433145  0.798816  0.661664  0.731269  0.453313  0.720585
# 2023-02-19  0.570383  0.280513  0.525930  0.401277  0.754004  0.224459
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-18  0.840732  0.230257  0.307581  0.053801  0.970646  0.624229
# 2023-02-16  0.916548  0.949671  0.079510  0.754622  0.268558  0.870638
#
#                   C7
# 2023-02-17  0.696618
# 2023-02-15  0.855661
# 2023-02-13  0.562924
# 2023-02-19  0.101457
# 2023-02-14  0.107962
# 2023-02-18  0.760958
# 2023-02-16  0.148585

# %%
dframe.sort_values(by = 'C1', ascending = False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-02-16  0.916548  0.949671  0.079510  0.754622  0.268558  0.870638
# 2023-02-18  0.840732  0.230257  0.307581  0.053801  0.970646  0.624229
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-19  0.570383  0.280513  0.525930  0.401277  0.754004  0.224459
# 2023-02-13  0.433145  0.798816  0.661664  0.731269  0.453313  0.720585
# 2023-02-15  0.369626  0.226232  0.112470  0.332292  0.177175  0.767421
# 2023-02-17  0.252374  0.729464  0.098727  0.326788  0.068944  0.815439
#
#                   C7
# 2023-02-16  0.148585
# 2023-02-18  0.760958
# 2023-02-14  0.107962
# 2023-02-19  0.101457
# 2023-02-13  0.562924
# 2023-02-15  0.855661
# 2023-02-17  0.696618

# %%
#Silme

# %%
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  NaN  4

# %%
del df1['B']

# %%
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  NaN

# %%
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
df5.pop('c')
# Out:
# row1     NaN
# row2    20.0
# Name: c, dtype: float64

# %%
df5
# Out:
#       a   b   d
# row1  1   2 NaN
# row2  5  10 NaN

# %%
dict = {'A' : pd.Series([1,2,3,11], index = ['a', 'b', 'c', 'd']),
        'B' : pd.Series([1,2,3,4], index = ['a', 'b', 'c', 'd'])}

df12 = pd.DataFrame(dict)
df12
# Out:
#     A  B
# a   1  1
# b   2  2
# c   3  3
# d  11  4

# %%
df12.drop(['A'], axis = 1, inplace = True)
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
df12
# Out:
#    B
# a  1
# b  2
# c  3
# d  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10, 100, 30)
df10 = pd.DataFrame({"C1" : col1, "C2" : col2})
df10
# Out:
#             C1  C2
# 0    10.000000  32
# 1    13.103448  57
# 2    16.206897  89
# 3    19.310345  67
# 4    22.413793  52
# 5    25.517241  68
# 6    28.620690  76
# 7    31.724138  35
# 8    34.827586  77
# 9    37.931034  61
# 10   41.034483  93
# 11   44.137931  72
# 12   47.241379  42
# 13   50.344828  34
# 14   53.448276  14
# 15   56.551724  52
# 16   59.655172  22
# 17   62.758621  27
# 18   65.862069  86
# 19   68.965517  41
# 20   72.068966  89
# 21   75.172414  52
# 22   78.275862  49
# 23   81.379310  93
# 24   84.482759  26
# 25   87.586207  86
# 26   90.689655  40
# 27   93.793103  39
# 28   96.896552  57
# 29  100.000000  99

# %%
df10 = df10.drop([17,18,19], axis = 0)
df10
# Out:
#             C1  C2
# 0    10.000000  32
# 1    13.103448  57
# 2    16.206897  89
# 3    19.310345  67
# 4    22.413793  52
# 5    25.517241  68
# 6    28.620690  76
# 7    31.724138  35
# 8    34.827586  77
# 9    37.931034  61
# 10   41.034483  93
# 11   44.137931  72
# 12   47.241379  42
# 13   50.344828  34
# 14   53.448276  14
# 15   56.551724  52
# 16   59.655172  22
# 20   72.068966  89
# 21   75.172414  52
# 22   78.275862  49
# 23   81.379310  93
# 24   84.482759  26
# 25   87.586207  86
# 26   90.689655  40
# 27   93.793103  39
# 28   96.896552  57
# 29  100.000000  99

# %%
df10.drop([16], axis = 0, inplace = True)
df10
# Out:
#             C1  C2
# 0    10.000000  32
# 1    13.103448  57
# 2    16.206897  89
# 3    19.310345  67
# 4    22.413793  52
# 5    25.517241  68
# 6    28.620690  76
# 7    31.724138  35
# 8    34.827586  77
# 9    37.931034  61
# 10   41.034483  93
# 11   44.137931  72
# 12   47.241379  42
# 13   50.344828  34
# 14   53.448276  14
# 15   56.551724  52
# 20   72.068966  89
# 21   75.172414  52
# 22   78.275862  49
# 23   81.379310  93
# 24   84.482759  26
# 25   87.586207  86
# 26   90.689655  40
# 27   93.793103  39
# 28   96.896552  57
# 29  100.000000  99

# %%
df10.drop(df10.index[5], inplace = True)

# %%
df10
# Out:
#             C1  C2
# 0    10.000000  32
# 1    13.103448  57
# 2    16.206897  89
# 3    19.310345  67
# 4    22.413793  52
# 6    28.620690  76
# 7    31.724138  35
# 8    34.827586  77
# 9    37.931034  61
# 10   41.034483  93
# 11   44.137931  72
# 12   47.241379  42
# 13   50.344828  34
# 14   53.448276  14
# 15   56.551724  52
# 20   72.068966  89
# 21   75.172414  52
# 22   78.275862  49
# 23   81.379310  93
# 24   84.482759  26
# 25   87.586207  86
# 26   90.689655  40
# 27   93.793103  39
# 28   96.896552  57
# 29  100.000000  99

# %%
df10 = df10.iloc[3:,]
df10
# Out:
#             C1  C2
# 3    19.310345  67
# 4    22.413793  52
# 6    28.620690  76
# 7    31.724138  35
# 8    34.827586  77
# 9    37.931034  61
# 10   41.034483  93
# 11   44.137931  72
# 12   47.241379  42
# 13   50.344828  34
# 14   53.448276  14
# 15   56.551724  52
# 20   72.068966  89
# 21   75.172414  52
# 22   78.275862  49
# 23   81.379310  93
# 24   84.482759  26
# 25   87.586207  86
# 26   90.689655  40
# 27   93.793103  39
# 28   96.896552  57
# 29  100.000000  99

# %%
df10 = df10.iloc[:-4,]
df10
# Out:
#            C1  C2
# 3   19.310345  67
# 4   22.413793  52
# 6   28.620690  76
# 7   31.724138  35
# 8   34.827586  77
# 9   37.931034  61
# 10  41.034483  93
# 11  44.137931  72
# 12  47.241379  42
# 13  50.344828  34
# 14  53.448276  14
# 15  56.551724  52
# 20  72.068966  89
# 21  75.172414  52
# 22  78.275862  49
# 23  81.379310  93
# 24  84.482759  26
# 25  87.586207  86

# %%
df10 = df10.iloc[:10,]
df10
# Out:
#            C1  C2
# 3   19.310345  67
# 4   22.413793  52
# 6   28.620690  76
# 7   31.724138  35
# 8   34.827586  77
# 9   37.931034  61
# 10  41.034483  93
# 11  44.137931  72
# 12  47.241379  42
# 13  50.344828  34

# %%
df10.index[df10['C2'] == 77].tolist()
# Out:
# [8]

# %%
df10.drop(df10.index[df10['C2'] == 77].tolist(), axis = 0, inplace = True)
# Out:
# C:\Users\ITU\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df10
# Out:
#            C1  C2
# 3   19.310345  67
# 4   22.413793  52
# 6   28.620690  76
# 7   31.724138  35
# 9   37.931034  61
# 10  41.034483  93
# 11  44.137931  72
# 12  47.241379  42
# 13  50.344828  34

# %%
df10 = df10[df10.C2 != 34]
df10
# Out:
#            C1  C2
# 3   19.310345  67
# 4   22.413793  52
# 6   28.620690  76
# 7   31.724138  35
# 9   37.931034  61
# 10  41.034483  93
# 11  44.137931  72
# 12  47.241379  42

# %%
df10 = df10[~(df10.C2.isin([67, 76]))]
df10
# Out:
#            C1  C2
# 4   22.413793  52
# 7   31.724138  35
# 9   37.931034  61
# 10  41.034483  93
# 11  44.137931  72
# 12  47.241379  42

# %%
df10 = df10[(df10.C2.isin([35, 61]))]
df10
# Out:
#           C1  C2
# 7  31.724138  35
# 9  37.931034  61

# %%
df13 = pd.DataFrame({'ID' : [1,2,3,4],
                     'Name' : ['Ali İhsan', 'Betül', 'Fatoş', 'Miray'],
                     'location' : ['India', 'Australia', 'UK', 'US']})
df13
# Out:
#    ID       Name   location
# 0   1  Ali İhsan      India
# 1   2      Betül  Australia
# 2   3      Fatoş         UK
# 3   4      Miray         US

# %%
ind = df13[((df13.Name == 'Fatoş') & (df13.ID == 3) & (df13.location == 'UK'))].index
df13.drop(ind, inplace = True)
df13
# Out:
#    ID       Name   location
# 0   1  Ali İhsan      India
# 1   2      Betül  Australia
# 3   4      Miray         US

# %%
#Veri Seçme (Data Selection)

# %%
df
# Out:
#   Language  Rating
# 0     Java       1
# 1   Python       2
# 2        C       3
# 3      C++       4

# %%
df.index = [1,2,3,4]
df
# Out:
#   Language  Rating
# 1     Java       1
# 2   Python       2
# 3        C       3
# 4      C++       4

# %%
df.loc[1]
# Out:
# Language    Java
# Rating         1
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Language    Python
# Rating           2
# Name: 2, dtype: object

# %%
df.loc[1:2]
# Out:
#   Language  Rating
# 1     Java       1
# 2   Python       2

# %%
df.iloc[1:2]
# Out:
#   Language  Rating
# 2   Python       2

# %%
df.loc[df.Rating > 2]
# Out:
#   Language  Rating
# 3        C       3
# 4      C++       4

# %%
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  NaN

# %%
df1.loc['a']
# Out:
# A    1.0
# Name: a, dtype: float64

# %%
df1.iloc['a']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-03fbf332515e> in <module>
# ----> 1 df1.iloc['a']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
#    1500             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
dframe
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-02-13  0.433145  0.798816  0.661664  0.731269  0.453313  0.720585
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-15  0.369626  0.226232  0.112470  0.332292  0.177175  0.767421
# 2023-02-16  0.916548  0.949671  0.079510  0.754622  0.268558  0.870638
# 2023-02-17  0.252374  0.729464  0.098727  0.326788  0.068944  0.815439
# 2023-02-18  0.840732  0.230257  0.307581  0.053801  0.970646  0.624229
# 2023-02-19  0.570383  0.280513  0.525930  0.401277  0.754004  0.224459
#
#                   C7
# 2023-02-13  0.562924
# 2023-02-14  0.107962
# 2023-02-15  0.855661
# 2023-02-16  0.148585
# 2023-02-17  0.696618
# 2023-02-18  0.760958
# 2023-02-19  0.101457

# %%
dframe['2023-02-13' : '2023-02-15']
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-02-13  0.433145  0.798816  0.661664  0.731269  0.453313  0.720585
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-15  0.369626  0.226232  0.112470  0.332292  0.177175  0.767421
#
#                   C7
# 2023-02-13  0.562924
# 2023-02-14  0.107962
# 2023-02-15  0.855661

# %%
dframe.loc[:, ['C1', 'C7']]
# Out:
#                   C1        C7
# 2023-02-13  0.433145  0.562924
# 2023-02-14  0.573700  0.107962
# 2023-02-15  0.369626  0.855661
# 2023-02-16  0.916548  0.148585
# 2023-02-17  0.252374  0.696618
# 2023-02-18  0.840732  0.760958
# 2023-02-19  0.570383  0.101457

# %%
dframe.loc['2023-02-13' : '2023-02-15', ['C1', 'C7']]
# Out:
#                   C1        C7
# 2023-02-13  0.433145  0.562924
# 2023-02-14  0.573700  0.107962
# 2023-02-15  0.369626  0.855661

# %%
dframe[dframe['C1'] > 0.5]
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-02-14  0.573700  0.344165  0.440763  0.061068  0.510655  0.418733
# 2023-02-16  0.916548  0.949671  0.079510  0.754622  0.268558  0.870638
# 2023-02-18  0.840732  0.230257  0.307581  0.053801  0.970646  0.624229
# 2023-02-19  0.570383  0.280513  0.525930  0.401277  0.754004  0.224459
#
#                   C7
# 2023-02-14  0.107962
# 2023-02-16  0.148585
# 2023-02-18  0.760958
# 2023-02-19  0.101457

# %%
dframe[(dframe['C1'] > 0.5) & (dframe['C4'] > 0.5)]
# Out:
#                   C1        C2       C3        C4        C5        C6  \
# 2023-02-16  0.916548  0.949671  0.07951  0.754622  0.268558  0.870638
#
#                   C7
# 2023-02-16  0.148585

# %%
dframe.iloc[0][0]
# Out:
# 0.4331447720174747

# %%
dframe.iloc[:, 0:3]
# Out:
#                   C1        C2        C3
# 2023-02-13  0.433145  0.798816  0.661664
# 2023-02-14  0.573700  0.344165  0.440763
# 2023-02-15  0.369626  0.226232  0.112470
# 2023-02-16  0.916548  0.949671  0.079510
# 2023-02-17  0.252374  0.729464  0.098727
# 2023-02-18  0.840732  0.230257  0.307581
# 2023-02-19  0.570383  0.280513  0.525930

# %%
dframe.iloc[0][0] = 10

# %%
dframe[dframe['C1'].isin([10, 20])]
# Out:
#               C1        C2        C3        C4        C5        C6        C7
# 2023-02-13  10.0  0.798816  0.661664  0.731269  0.453313  0.720585  0.562924

# %%
#Değer Atama

# %%
dframe['C1'] = 888
dframe
# Out:
#              C1        C2        C3        C4        C5        C6        C7
# 2023-02-13  888  0.798816  0.661664  0.731269  0.453313  0.720585  0.562924
# 2023-02-14  888  0.344165  0.440763  0.061068  0.510655  0.418733  0.107962
# 2023-02-15  888  0.226232  0.112470  0.332292  0.177175  0.767421  0.855661
# 2023-02-16  888  0.949671  0.079510  0.754622  0.268558  0.870638  0.148585
# 2023-02-17  888  0.729464  0.098727  0.326788  0.068944  0.815439  0.696618
# 2023-02-18  888  0.230257  0.307581  0.053801  0.970646  0.624229  0.760958
# 2023-02-19  888  0.280513  0.525930  0.401277  0.754004  0.224459  0.101457

# %%
dframe.loc[0:3, 'C6'] = 777
dframe
# Out:
# <ipython-input-78-ce7bd2621023>:1: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   dframe.loc[0:3, 'C6'] = 777
#              C1        C2        C3        C4        C5          C6        C7
# 2023-02-13  888  0.798816  0.661664  0.731269  0.453313  777.000000  0.562924
# 2023-02-14  888  0.344165  0.440763  0.061068  0.510655  777.000000  0.107962
# 2023-02-15  888  0.226232  0.112470  0.332292  0.177175  777.000000  0.855661
# 2023-02-16  888  0.949671  0.079510  0.754622  0.268558    0.870638  0.148585
# 2023-02-17  888  0.729464  0.098727  0.326788  0.068944    0.815439  0.696618
# 2023-02-18  888  0.230257  0.307581  0.053801  0.970646    0.624229  0.760958
# 2023-02-19  888  0.280513  0.525930  0.401277  0.754004    0.224459  0.101457

# %%
dframe.iloc[0, 2] = 333

# %%
dframe
# Out:
#              C1        C2          C3        C4        C5          C6  \
# 2023-02-13  888  0.798816  333.000000  0.731269  0.453313  777.000000
# 2023-02-14  888  0.344165    0.440763  0.061068  0.510655  777.000000
# 2023-02-15  888  0.226232    0.112470  0.332292  0.177175  777.000000
# 2023-02-16  888  0.949671    0.079510  0.754622  0.268558    0.870638
# 2023-02-17  888  0.729464    0.098727  0.326788  0.068944    0.815439
# 2023-02-18  888  0.230257    0.307581  0.053801  0.970646    0.624229
# 2023-02-19  888  0.280513    0.525930  0.401277  0.754004    0.224459
#
#                   C7
# 2023-02-13  0.562924
# 2023-02-14  0.107962
# 2023-02-15  0.855661
# 2023-02-16  0.148585
# 2023-02-17  0.696618
# 2023-02-18  0.760958
# 2023-02-19  0.101457

# %%
dframe.iloc[0, 2] = 555

# %%
dframe
# Out:
#              C1        C2          C3        C4        C5          C6  \
# 2023-02-13  888  0.798816  555.000000  0.731269  0.453313  777.000000
# 2023-02-14  888  0.344165    0.440763  0.061068  0.510655  777.000000
# 2023-02-15  888  0.226232    0.112470  0.332292  0.177175  777.000000
# 2023-02-16  888  0.949671    0.079510  0.754622  0.268558    0.870638
# 2023-02-17  888  0.729464    0.098727  0.326788  0.068944    0.815439
# 2023-02-18  888  0.230257    0.307581  0.053801  0.970646    0.624229
# 2023-02-19  888  0.280513    0.525930  0.401277  0.754004    0.224459
#
#                   C7
# 2023-02-13  0.562924
# 2023-02-14  0.107962
# 2023-02-15  0.855661
# 2023-02-16  0.148585
# 2023-02-17  0.696618
# 2023-02-18  0.760958
# 2023-02-19  0.101457

# %%
import warnings
warnings.filterwarnings("ignore")
dframe.loc[0:7, 'C7'] = np.NaN
dframe.loc[0:2, 'C6'] = np.NaN
dframe.loc[5:6, 'C5'] = np.NaN
dframe
# Out:
#              C1        C2          C3        C4        C5          C6  C7
# 2023-02-13  888  0.798816  555.000000  0.731269  0.453313         NaN NaN
# 2023-02-14  888  0.344165    0.440763  0.061068  0.510655         NaN NaN
# 2023-02-15  888  0.226232    0.112470  0.332292  0.177175  777.000000 NaN
# 2023-02-16  888  0.949671    0.079510  0.754622  0.268558    0.870638 NaN
# 2023-02-17  888  0.729464    0.098727  0.326788  0.068944    0.815439 NaN
# 2023-02-18  888  0.230257    0.307581  0.053801       NaN    0.624229 NaN
# 2023-02-19  888  0.280513    0.525930  0.401277  0.754004    0.224459 NaN

# %%
dframe.notna()
# Out:
#               C1    C2    C3    C4     C5     C6     C7
# 2023-02-13  True  True  True  True   True  False  False
# 2023-02-14  True  True  True  True   True  False  False
# 2023-02-15  True  True  True  True   True   True  False
# 2023-02-16  True  True  True  True   True   True  False
# 2023-02-17  True  True  True  True   True   True  False
# 2023-02-18  True  True  True  True  False   True  False
# 2023-02-19  True  True  True  True   True   True  False

# %%
dframe.isna()
# Out:
#                C1     C2     C3     C4     C5     C6    C7
# 2023-02-13  False  False  False  False  False   True  True
# 2023-02-14  False  False  False  False  False   True  True
# 2023-02-15  False  False  False  False  False  False  True
# 2023-02-16  False  False  False  False  False  False  True
# 2023-02-17  False  False  False  False  False  False  True
# 2023-02-18  False  False  False  False   True  False  True
# 2023-02-19  False  False  False  False  False  False  True

# %%
dframe = dframe.fillna(1020)
dframe
# Out:
#              C1        C2          C3        C4           C5           C6  \
# 2023-02-13  888  0.798816  555.000000  0.731269     0.453313  1020.000000
# 2023-02-14  888  0.344165    0.440763  0.061068     0.510655  1020.000000
# 2023-02-15  888  0.226232    0.112470  0.332292     0.177175   777.000000
# 2023-02-16  888  0.949671    0.079510  0.754622     0.268558     0.870638
# 2023-02-17  888  0.729464    0.098727  0.326788     0.068944     0.815439
# 2023-02-18  888  0.230257    0.307581  0.053801  1020.000000     0.624229
# 2023-02-19  888  0.280513    0.525930  0.401277     0.754004     0.224459
#
#                 C7
# 2023-02-13  1020.0
# 2023-02-14  1020.0
# 2023-02-15  1020.0
# 2023-02-16  1020.0
# 2023-02-17  1020.0
# 2023-02-18  1020.0
# 2023-02-19  1020.0

# %%
dframe.loc[0:5, 'C7'] = np.NaN
dframe.loc[0:2, 'C6'] = np.NaN
dframe.loc[5:6, 'C5'] = np.NaN
dframe
# Out:
#              C1        C2          C3        C4        C5          C6      C7
# 2023-02-13  888  0.798816  555.000000  0.731269  0.453313         NaN     NaN
# 2023-02-14  888  0.344165    0.440763  0.061068  0.510655         NaN     NaN
# 2023-02-15  888  0.226232    0.112470  0.332292  0.177175  777.000000     NaN
# 2023-02-16  888  0.949671    0.079510  0.754622  0.268558    0.870638     NaN
# 2023-02-17  888  0.729464    0.098727  0.326788  0.068944    0.815439     NaN
# 2023-02-18  888  0.230257    0.307581  0.053801       NaN    0.624229  1020.0
# 2023-02-19  888  0.280513    0.525930  0.401277  0.754004    0.224459  1020.0

# %%
dframe.fillna(value = {'C5': 123, 'C6':789})
# Out:
#              C1        C2          C3        C4          C5          C6  \
# 2023-02-13  888  0.798816  555.000000  0.731269    0.453313  789.000000
# 2023-02-14  888  0.344165    0.440763  0.061068    0.510655  789.000000
# 2023-02-15  888  0.226232    0.112470  0.332292    0.177175  777.000000
# 2023-02-16  888  0.949671    0.079510  0.754622    0.268558    0.870638
# 2023-02-17  888  0.729464    0.098727  0.326788    0.068944    0.815439
# 2023-02-18  888  0.230257    0.307581  0.053801  123.000000    0.624229
# 2023-02-19  888  0.280513    0.525930  0.401277    0.754004    0.224459
#
#                 C7
# 2023-02-13     NaN
# 2023-02-14     NaN
# 2023-02-15     NaN
# 2023-02-16     NaN
# 2023-02-17     NaN
# 2023-02-18  1020.0
# 2023-02-19  1020.0

# %%
dframe.fillna(value = {'C7' : 789}, limit =3)
# Out:
#              C1        C2          C3        C4        C5          C6      C7
# 2023-02-13  888  0.798816  555.000000  0.731269  0.453313         NaN   789.0
# 2023-02-14  888  0.344165    0.440763  0.061068  0.510655         NaN   789.0
# 2023-02-15  888  0.226232    0.112470  0.332292  0.177175  777.000000   789.0
# 2023-02-16  888  0.949671    0.079510  0.754622  0.268558    0.870638     NaN
# 2023-02-17  888  0.729464    0.098727  0.326788  0.068944    0.815439     NaN
# 2023-02-18  888  0.230257    0.307581  0.053801       NaN    0.624229  1020.0
# 2023-02-19  888  0.280513    0.525930  0.401277  0.754004    0.224459  1020.0
